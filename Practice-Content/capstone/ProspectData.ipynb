# %% [markdown]
# ### Prospect Data

# %%
import pandas as pd
import numpy as np
from scrapy.selector import Selector
from scrapy.http import HtmlResponse
import requests
import time
from bs4 import BeautifulSoup
from selenium import webdriver
import random
import string

chromedriver = "/Users/Carter/Desktop/chromedriver"

# %%
browser = webdriver.Chrome(executable_path = chromedriver)

# %%
browser.get('http://basketball.realgm.com/nba/draft/prospects/stats')
HTML = browser.page_source

# %%
prospects = []

for i in range(1,61):
    path = "//tbody/tr[%s]//text()" %i
    player = Selector(text=HTML).xpath(path).extract()
    
    
    prospects.append({
        "Player": player[0],
        "Team": player[1],
        "GP": player[2],
        "MPG": player[3],
        "FGM": player[4],
        "FGA": player[5],
        "FG%": player[6],
        "3PM": player[7],
        "3PA": player[7],
        "3P%": player[9],
        "FTM": player[10],
        "FTA": player[11],
        "FT%": player[12],
        "ORB": player[13],
        "DRB": player[14],
        "RPG": player[15],
        "APG": player[16],
        "SPG": player[17],
        "BPG": player[18],
        "PPG": player[19]
    })
    
browser.quit()

# %%
df = pd.DataFrame(prospects)
df.head()
# Out:
#     3P%  3PA  3PM  APG  BPG  DRB   FG%   FGA  FGM   FT%  FTA  FTM  GP   MPG  \
# 0  .413  2.1  2.1  5.9  1.2  4.4  .476  17.6  8.4  .649  6.7  4.4  25  35.7
# 1  .362  2.0  2.0  2.2  0.4  7.6  .466  16.1  7.5  .887  6.7  5.9  29  35.1
# 2  .397  2.7  2.7  2.3  0.5  2.2  .450  14.7  6.6  .822  4.7  3.9  38  32.1
# 3  .438  2.4  2.4  2.5  0.4  3.9  .490  13.1  6.4  .856  5.1  4.3  37  35.5
# 4  .373  2.5  2.5  2.1  0.1  4.9  .439  13.4  5.9  .754  5.5  4.2  36  35.1
#
#    ORB   PPG          Player   RPG  SPG  Team
# 0  1.3  23.2  Markelle Fultz   5.7  1.6    UW
# 1  2.6  23.0     Alec Peters  10.1  0.8   VAL
# 2  0.3  19.8      Malik Monk   2.5  0.9    UK
# 3  1.2  19.5    Luke Kennard   5.1  0.8  DUKE
# 4  0.7  18.5  Trevon Bluiett   5.7  0.9   XAV

# %%
df.shape
# Out:
# (60, 20)

# %%
cols = df.columns.tolist()

# %%
cols = ['Player', 'Team', 'GP', 'MPG', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'ORB', 'DRB', 'RPG', 'APG', 'SPG', 'BPG', 'PPG']

# %%
df = df[cols]

# %%
df
# Out:
#                   Player    Team  GP   MPG  FGM   FGA   FG%  3PM  3PA   3P%  \
# 0         Markelle Fultz      UW  25  35.7  8.4  17.6  .476  2.1  2.1  .413
# 1            Alec Peters     VAL  29  35.1  7.5  16.1  .466  2.0  2.0  .362
# 2             Malik Monk      UK  38  32.1  6.6  14.7  .450  2.7  2.7  .397
# 3           Luke Kennard    DUKE  37  35.5  6.4  13.1  .490  2.4  2.4  .438
# 4         Trevon Bluiett     XAV  36  35.1  5.9  13.4  .439  2.5  2.5  .373
# 5         Justin Jackson     UNC  38  31.7  6.6  14.8  .447  2.7  2.7  .380
# 6          Marcus Foster      CU  35  30.9  7.0  15.2  .461  2.1  2.1  .341
# 7           Dennis Smith    NCST  32  34.8  6.0  13.1  .455  1.7  1.7  .359
# 8      Jaron Blossomgame    CLEM  33  34.3  6.7  13.4  .499  0.7  0.7  .255
# 9       Johnathan Motley      BU  34  30.2  6.6  12.7  .522  0.3  0.3  .281
# 10         Allonzo Trier  U of A  18  31.9  5.1  11.0  .460  1.9  1.9  .391
# ...

# %%
df.to_csv(path_or_buf= 'prospects.csv')
